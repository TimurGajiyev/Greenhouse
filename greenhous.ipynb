# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib as mlb

# %%
df_fuel = pd.read_excel(r"NAc Agro.xlsx")
df_fuel
# Out:
#     Unnamed: 0          Unnamed: 1       Unnamed: 2      Unnamed: 3  \
# 0          NaN                 NaN         Hour/Day         Monthly
# 1         31.0                 Jan               15             465
# 2         28.0                 Feb               13             364
# 3         31.0                 Mar               12             372
# 4         30.0                 Apr                2              60
# 5         31.0                 May              NaN               0
# 6         30.0                June              NaN               0
# 7         31.0                July              NaN               0
# 8         31.0                 Aug              NaN               0
# 9         30.0                 Sep              NaN               0
# 10        31.0                 Oct                3              93
# 11        30.0                 Nov               13             390
# 12        31.0                 Dec               17             527
# ...

# %%
# Select rows 0-12 and columns 0-14 (up to "Grid Payments Original")
df_selected = df_fuel.iloc[0:13, 0:15]  # 13 rows (0-12) and 15 columns (0-14)
print("Selected data shape:", df_selected.shape)
print("\nSelected DataFrame:")
print(df_selected)
# Out:
# Selected data shape: (13, 15)
#
# Selected DataFrame:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3       Unnamed: 4  \
# 0          NaN        NaN   Hour/Day    Monthly  Consumption kWh
# 1         31.0        Jan         15        465          5580000
# 2         28.0        Feb         13        364          4368000
# 3         31.0        Mar         12        372          4464000
# 4         30.0        Apr          2         60           720000
# 5         31.0        May        NaN          0                0
# 6         30.0       June        NaN          0                0
# 7         31.0       July        NaN          0                0
# 8         31.0        Aug        NaN          0                0
# 9         30.0        Sep        NaN          0                0
# 10        31.0        Oct          3         93          1116000
# 11        30.0        Nov         13        390          4680000
# 12        31.0        Dec         17        527          6324000
#
# ...

# %%
# Manually created variables with values from the table data

# Days in month (column 0)
days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31, 0]  # Total row as 0

# Month names (column 1) 
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Total']

# Hour/Day (column 2)
hours_per_day = [15, 13, 12, 2, 0, 0, 0, 0, 0, 3, 13, 17, 0]  # Total row as 0

# Monthly totals (column 3)
monthly_totals = [465, 364, 372, 60, 0, 0, 0, 0, 0, 93, 390, 527, 2271]

print("First 4 columns created:")
print(f"Days: {days_in_month}")
print(f"Months: {months}")
print(f"Hours/Day: {hours_per_day}")
print(f"Monthly: {monthly_totals}")
# Out:
# First 4 columns created:
# Days: [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31, 0]
# Months: ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Total']
# Hours/Day: [15, 13, 12, 2, 0, 0, 0, 0, 0, 3, 13, 17, 0]
# Monthly: [465, 364, 372, 60, 0, 0, 0, 0, 0, 93, 390, 527, 2271]

# %%
# Consumption kWh (column 4)
consumption_kwh = [5580000, 4368000, 4464000, 720000, 0, 0, 0, 0, 0, 1116000, 4680000, 6324000, 27252000]

# Power produced kWh (column 5)
power_produced_kwh = [2557500, 2002000, 2046000, 330000, 0, 0, 0, 0, 0, 511500, 2145000, 2898500, 12490500]

# Gas Consumed m3 (column 6)
gas_consumed_m3 = [639375, 500500, 511500, 82500, 0, 0, 0, 0, 0, 127875, 536250, 724625, 3122625]

# Gas price Euro (column 7)
gas_price_euro = [39346, 30800, 31477, 5077, 0, 0, 0, 0, 0, 7869, 33000, 44592, 192162]

# Maintenance Euro (column 8)
maint_euro = [23608, 18480, 18886, 3046, 0, 0, 0, 0, 0, 4722, 19800, 26755, 115297]

print("Energy and cost columns created:")
print(f"Consumption kWh: {consumption_kwh[:5]}...")  # Show first 5 values
print(f"Power produced kWh: {power_produced_kwh[:5]}...")
print(f"Gas consumed m3: {gas_consumed_m3[:5]}...")
print(f"Gas price Euro: {gas_price_euro[:5]}...")
print(f"Maintenance Euro: {maint_euro[:5]}...")
# Out:
# Energy and cost columns created:
# Consumption kWh: [5580000, 4368000, 4464000, 720000, 0]...
# Power produced kWh: [2557500, 2002000, 2046000, 330000, 0]...
# Gas consumed m3: [639375, 500500, 511500, 82500, 0]...
# Gas price Euro: [39346, 30800, 31477, 5077, 0]...
# Maintenance Euro: [23608, 18480, 18886, 3046, 0]...

# %%
# Total Costs E (column 9)
total_costs_e = [62954, 49280, 50363, 8123, 0, 0, 0, 0, 0, 12591, 52800, 71348, 307458]

# Cost of replaced Grid (column 10)
cost_replaced_grid = [137712, 107800, 110169, 17769, 0, 0, 0, 0, 0, 27542, 115500, 156073, 672565]

# Profit (column 11)
profit = [74758, 58520, 59806, 9646, 0, 0, 0, 0, 0, 14952, 62700, 84725, 365107]

# Grid kWh (column 12)
grid_kwh = [3022500, 2366000, 2418000, 390000, 0, 0, 0, 0, 0, 604500, 2535000, 3425500, 14761500]

# Grid payments (column 13)
grid_payments = [162750, 127400, 130200, 21000, 0, 0, 0, 0, 0, 32550, 136500, 184450, 794850]

print("Financial columns created:")
print(f"Total costs E: {total_costs_e[:5]}...")
print(f"Cost replaced grid: {cost_replaced_grid[:5]}...")
print(f"Profit: {profit[:5]}...")
print(f"Grid kWh: {grid_kwh[:5]}...")
print(f"Grid payments: {grid_payments[:5]}...")
# Out:
# Financial columns created:
# Total costs E: [62954, 49280, 50363, 8123, 0]...
# Cost replaced grid: [137712, 107800, 110169, 17769, 0]...
# Profit: [74758, 58520, 59806, 9646, 0]...
# Grid kWh: [3022500, 2366000, 2418000, 390000, 0]...
# Grid payments: [162750, 127400, 130200, 21000, 0]...

# %%
# Grid Payments Original (column 14)
grid_payments_original = [300462, 235200, 240369, 38769, 0, 0, 0, 0, 0, 60092, 252000, 340523, 1467415]

print("Final column created:")
print(f"Grid payments original: {grid_payments_original}")

print("\n" + "="*60)
print("ALL VARIABLES MANUALLY CREATED WITH TABLE VALUES")
print("="*60)

# Summary of all variables
all_variables = {
    'days_in_month': days_in_month,
    'months': months,
    'hours_per_day': hours_per_day,
    'monthly_totals': monthly_totals,
    'consumption_kwh': consumption_kwh,
    'power_produced_kwh': power_produced_kwh,
    'gas_consumed_m3': gas_consumed_m3,
    'gas_price_euro': gas_price_euro,
    'maint_euro': maint_euro,
    'total_costs_e': total_costs_e,
    'cost_replaced_grid': cost_replaced_grid,
    'profit': profit,
    'grid_kwh': grid_kwh,
    'grid_payments': grid_payments,
    'grid_payments_original': grid_payments_original
}

print("Variables created:")
for var_name in all_variables.keys():
    print(f"  {var_name}")
    
print(f"\nTotal: {len(all_variables)} variables")
print("Each variable contains 13 values (12 months + 1 total)")

# Example usage
print(f"\nExample - January data:")
print(f"Month: {months[0]}")
print(f"Days: {days_in_month[0]}")
print(f"Consumption: {consumption_kwh[0]:,} kWh")
print(f"Profit: {profit[0]:,} Euro")
# Out:
# Final column created:
# Grid payments original: [300462, 235200, 240369, 38769, 0, 0, 0, 0, 0, 60092, 252000, 340523, 1467415]
#
# ...
# ALL VARIABLES MANUALLY CREATED WITH TABLE VALUES
# ...
# Variables created:
#   days_in_month
#   months
#   hours_per_day
#   monthly_totals
#   consumption_kwh
#   power_produced_kwh
#   gas_consumed_m3
#   gas_price_euro
#   maint_euro
#   total_costs_e
#   cost_replaced_grid
#   profit
#   grid_kwh
#   grid_payments
#   grid_payments_original
#
# Total: 15 variables
# Each variable contains 13 values (12 months + 1 total)
#
# Example - January data:
# Month: Jan
# Days: 31
# Consumption: 5,580,000 kWh
# Profit: 74,758 Euro
